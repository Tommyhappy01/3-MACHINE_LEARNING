# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("stage_1.csv")

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'vat', 'km', 'registration',
#        'prev_owner', 'hp', 'Type', 'Next Inspection', 'Inspection new',
#        'Warranty', 'Make', 'Model', 'First Registration', 'Body Color',
#        'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Gearing Type',
#        'Displacement', 'Weight', 'Drive chain', 'Consumption', 'CO2 Emission',
#        'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'Emission Label', 'Gears', 'Country version'],
#       dtype='object')

# %% [markdown]
# ### Öncelikle Dublicate satırları düşüyoruz.

# %%
df.shape
# Out:
# (15919, 34)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (14433, 34)

# %% [markdown]
# ### make_model
# **Bu sütunda yer alan veriler üzerinde herhangi bir cleaning işlemi yapmaya gerek yok.**

# %%
df.make_model.sample(5)
# Out:
# 2973            Audi A3
# 2075            Audi A1
# 5933         Opel Astra
# 15656    Renault Espace
# 14488      Renault Clio
# Name: make_model, dtype: object

# %% [markdown]
# ### body_type
# **bu sütun üzerinde data cleaning işllemi

# %%
df.body_type.isnull().sum()
# Out:
# 60

# %%
df.body_type.value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.drop_duplicates()
# Out:
#            make_model body_type  price               vat         km  \
# 0             Audi A1    Sedans  15770    VAT deductible  56,013 km
# 1             Audi A1    Sedans  14500  Price negotiable  80,000 km
# 2             Audi A1    Sedans  14640    VAT deductible  83,450 km
# 3             Audi A1    Sedans  14500               NaN  73,000 km
# 4             Audi A1    Sedans  16790               NaN  16,200 km
# ...               ...       ...    ...               ...        ...
# 15913  Renault Espace       Van  39950    VAT deductible   1,000 km
# 15914  Renault Espace       Van  39950    VAT deductible       - km
# 15915  Renault Espace       Van  39885    VAT deductible   9,900 km
# 15916  Renault Espace       Van  39875    VAT deductible      15 km
# 15918  Renault Espace       Van  40999    VAT deductible       - km
#
#       registration         prev_owner      hp  \
# 0          01/2016  2 previous owners   66 kW
# 1          03/2017                NaN  141 kW
# 2          02/2016   1 previous owner   85 kW
# 3          08/2016   1 previous owner   66 kW
# 4          05/2016   1 previous owner   66 kW
# ...            ...                ...     ...
# 15913      04/2019                NaN  165 kW
# 15914          -/-                NaN  147 kW
# 15915      01/2019   1 previous owner  165 kW
# 15916      03/2019   1 previous owner  146 kW
# 15918      01/2019   1 previous owner  165 kW
#
#                                                     Type  \
# 0        ['', 'Used', '', 'Diesel (Particulate Filter)']
# 1                           ['', 'Used', '', 'Gasoline']
# 2        ['', 'Used', '', 'Diesel (Particulate Filter)']
# 3        ['', 'Used', '', 'Diesel (Particulate Filter)']
# 4        ['', 'Used', '', 'Diesel (Particulate Filter)']
# ...                                                  ...
# 15913              ['', 'Demonstration', '', 'Super 95']
# 15914     ['', 'New', '', 'Diesel (Particulate Filter)']
# 15915  ['', 'Used', '', 'Super 95 / Super Plus 98 (Pa...
# 15916               ['', 'Pre-registered', '', 'Diesel']
# 15918              ['', 'Demonstration', '', 'Super 95']
#
#                                   Next Inspection  \
# 0       ['\n06/2021\n', '\n99 g CO2/km (comb)\n']
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 15913                                         NaN
# 15914                                         NaN
# 15915  ['\n01/2022\n', '\n168 g CO2/km (comb)\n']
# 15916                                         NaN
# 15918                                         NaN
#
#                                Inspection new  Warranty         Make  \
# 0                   ['\nYes\n', '\nEuro 6\n']       NaN     \nAudi\n
# 1                                         NaN       NaN     \nAudi\n
# 2                                         NaN       NaN     \nAudi\n
# 3                                         NaN       NaN     \nAudi\n
# 4      ['\nYes\n', '\n109 g CO2/km (comb)\n']       NaN     \nAudi\n
# ...                                       ...       ...          ...
# 15913                                     NaN       NaN  \nRenault\n
# 15914                                     NaN       NaN  \nRenault\n
# 15915                                     NaN       NaN  \nRenault\n
# 15916         ['\nYes\n', '\nEuro 6d-TEMP\n']       NaN  \nRenault\n
# 15918  ['\nYes\n', '\n153 g CO2/km (comb)\n']       NaN  \nRenault\n
#
#                         Model    First Registration             Body Color  \
# 0          ['\n', 'A1', '\n']  ['\n', '2016', '\n']  ['\n', 'Black', '\n']
# 1          ['\n', 'A1', '\n']  ['\n', '2017', '\n']    ['\n', 'Red', '\n']
# 2          ['\n', 'A1', '\n']  ['\n', '2016', '\n']  ['\n', 'Black', '\n']
# 3          ['\n', 'A1', '\n']  ['\n', '2016', '\n']  ['\n', 'Brown', '\n']
# 4          ['\n', 'A1', '\n']  ['\n', '2016', '\n']  ['\n', 'Black', '\n']
# ...                       ...                   ...                    ...
# 15913  ['\n', 'Espace', '\n']  ['\n', '2019', '\n']  ['\n', 'White', '\n']
# 15914  ['\n', 'Espace', '\n']                   NaN   ['\n', 'Grey', '\n']
# 15915  ['\n', 'Espace', '\n']  ['\n', '2019', '\n']   ['\n', 'Grey', '\n']
# 15916  ['\n', 'Espace', '\n']  ['\n', '2019', '\n']  ['\n', 'White', '\n']
# 15918  ['\n', 'Espace', '\n']  ['\n', '2019', '\n']   ['\n', 'Grey', '\n']
#
#                         Upholstery                    Body Nr. of Doors  \
# 0             ['\nCloth, Black\n']  ['\n', 'Sedans', '\n']    ['\n5\n']
# 1              ['\nCloth, Grey\n']  ['\n', 'Sedans', '\n']    ['\n3\n']
# 2             ['\nCloth, Black\n']  ['\n', 'Sedans', '\n']    ['\n4\n']
# 3                              NaN  ['\n', 'Sedans', '\n']    ['\n3\n']
# 4             ['\nCloth, Black\n']  ['\n', 'Sedans', '\n']    ['\n5\n']
# ...                            ...                     ...          ...
# 15913  ['\nFull leather, Brown\n']     ['\n', 'Van', '\n']    ['\n5\n']
# 15914                          NaN     ['\n', 'Van', '\n']    ['\n5\n']
# 15915                ['\nCloth\n']     ['\n', 'Van', '\n']    ['\n5\n']
# 15916  ['\nFull leather, Black\n']     ['\n', 'Van', '\n']    ['\n5\n']
# 15918  ['\nFull leather, Brown\n']     ['\n', 'Van', '\n']    ['\n5\n']
#
#       Nr. of Seats               Gearing Type      Displacement  \
# 0        ['\n5\n']  ['\n', 'Automatic', '\n']  ['\n1,422 cc\n']
# 1        ['\n4\n']  ['\n', 'Automatic', '\n']  ['\n1,798 cc\n']
# 2        ['\n4\n']  ['\n', 'Automatic', '\n']  ['\n1,598 cc\n']
# 3        ['\n4\n']  ['\n', 'Automatic', '\n']  ['\n1,422 cc\n']
# 4        ['\n5\n']  ['\n', 'Automatic', '\n']  ['\n1,422 cc\n']
# ...            ...                        ...               ...
# 15913    ['\n7\n']  ['\n', 'Automatic', '\n']  ['\n1,798 cc\n']
# 15914    ['\n5\n']  ['\n', 'Automatic', '\n']  ['\n1,997 cc\n']
# 15915    ['\n5\n']  ['\n', 'Automatic', '\n']  ['\n1,798 cc\n']
# 15916    ['\n7\n']  ['\n', 'Automatic', '\n']  ['\n1,997 cc\n']
# 15918    ['\n5\n']  ['\n', 'Automatic', '\n']  ['\n1,798 cc\n']
#
#                  Weight    Drive chain  \
# 0      ['\n1,220 kg\n']  ['\nfront\n']
# 1      ['\n1,255 kg\n']  ['\nfront\n']
# 2                   NaN  ['\nfront\n']
# 3      ['\n1,195 kg\n']            NaN
# 4                   NaN  ['\nfront\n']
# ...                 ...            ...
# 15913               NaN  ['\nfront\n']
# 15914  ['\n1,758 kg\n']  ['\nfront\n']
# 15915  ['\n1,708 kg\n']  ['\nfront\n']
# 15916               NaN  ['\nfront\n']
# 15918  ['\n1,685 kg\n']    ['\n4WD\n']
#
#                                              Consumption  \
# 0      [['3.8 l/100 km (comb)'], ['4.3 l/100 km (city...
# 1      [['5.6 l/100 km (comb)'], ['7.1 l/100 km (city...
# 2      [['3.8 l/100 km (comb)'], ['4.4 l/100 km (city...
# 3      [['3.8 l/100 km (comb)'], ['4.3 l/100 km (city...
# 4      [['4.1 l/100 km (comb)'], ['4.6 l/100 km (city...
# ...                                                  ...
# 15913  [['6.8 l/100 km (comb)'], ['8.7 l/100 km (city...
# 15914  [['5.3 l/100 km (comb)'], ['6.2 l/100 km (city...
# 15915  ['\n', '7.4 l/100 km (comb)', '\n', '9.2 l/100...
# 15916  [['5.3 l/100 km (comb)'], ['6.2 l/100 km (city...
# 15918  [['6.8 l/100 km (comb)'], ['8.7 l/100 km (city...
#
#                       CO2 Emission        Emission Class  \
# 0       ['\n99 g CO2/km (comb)\n']        ['\nEuro 6\n']
# 1      ['\n129 g CO2/km (comb)\n']        ['\nEuro 6\n']
# 2       ['\n99 g CO2/km (comb)\n']        ['\nEuro 6\n']
# 3       ['\n99 g CO2/km (comb)\n']        ['\nEuro 6\n']
# 4      ['\n109 g CO2/km (comb)\n']        ['\nEuro 6\n']
# ...                            ...                   ...
# 15913  ['\n153 g CO2/km (comb)\n']        ['\nEuro 6\n']
# 15914  ['\n139 g CO2/km (comb)\n']                   NaN
# 15915  ['\n168 g CO2/km (comb)\n']                   NaN
# 15916  ['\n139 g CO2/km (comb)\n']  ['\nEuro 6d-TEMP\n']
# 15918  ['\n153 g CO2/km (comb)\n']        ['\nEuro 6\n']
#
#                                \nComfort & Convenience\n  \
# 0      ['Air conditioning', 'Armrest', 'Automatic cli...
# 1      ['Air conditioning', 'Automatic climate contro...
# 2      ['Air conditioning', 'Cruise control', 'Electr...
# 3      ['Air suspension', 'Armrest', 'Auxiliary heati...
# 4      ['Air conditioning', 'Armrest', 'Automatic cli...
# ...                                                  ...
# 15913  ['Air conditioning', 'Armrest', 'Automatic cli...
# 15914  ['Air conditioning', 'Automatic climate contro...
# 15915  ['Air conditioning', 'Automatic climate contro...
# 15916  ['Air conditioning', 'Armrest', 'Automatic cli...
# 15918  ['Air conditioning', 'Automatic climate contro...
#
#                                \nEntertainment & Media\n  \
# 0      ['Bluetooth', 'Hands-free equipment', 'On-boar...
# 1      ['Bluetooth', 'Hands-free equipment', 'On-boar...
# 2                           ['MP3', 'On-board computer']
# 3      ['Bluetooth', 'CD player', 'Hands-free equipme...
# 4      ['Bluetooth', 'CD player', 'Hands-free equipme...
# ...                                                  ...
# 15913  ['Bluetooth', 'Digital radio', 'Hands-free equ...
# 15914  ['Bluetooth', 'Digital radio', 'Hands-free equ...
# 15915  ['Bluetooth', 'Digital radio', 'Hands-free equ...
# 15916  ['Bluetooth', 'Hands-free equipment', 'On-boar...
# 15918                                            ['USB']
#
#                                               \nExtras\n  \
# 0      ['Alloy wheels', 'Catalytic Converter', 'Voice...
# 1      ['Alloy wheels', 'Sport seats', 'Sport suspens...
# 2                      ['Alloy wheels', 'Voice Control']
# 3       ['Alloy wheels', 'Sport seats', 'Voice Control']
# 4      ['Alloy wheels', 'Sport package', 'Sport suspe...
# ...                                                  ...
# 15913  ['Alloy wheels', 'Catalytic Converter', 'Sport...
# 15914                   ['Alloy wheels', 'Touch screen']
# 15915  ['Alloy wheels', 'Touch screen', 'Voice Control']
# 15916                                   ['Alloy wheels']
# 15918                   ['Alloy wheels', 'Touch screen']
#
#                                    \nSafety & Security\n     Emission Label  \
# 0      ['ABS', 'Central door lock', 'Daytime running ...                NaN
# 1      ['ABS', 'Central door lock', 'Central door loc...  ['\n4 (Green)\n']
# 2      ['ABS', 'Central door lock', 'Daytime running ...  ['\n4 (Green)\n']
# 3      ['ABS', 'Alarm system', 'Central door lock wit...                NaN
# 4      ['ABS', 'Central door lock', 'Driver-side airb...                NaN
# ...                                                  ...                ...
# 15913  ['ABS', 'Adaptive Cruise Control', 'Blind spot...  ['\n4 (Green)\n']
# 15914  ['ABS', 'Central door lock', 'Central door loc...                NaN
# 15915  ['ABS', 'Adaptive Cruise Control', 'Blind spot...                NaN
# 15916  ['ABS', 'Adaptive Cruise Control', 'Blind spot...                NaN
# 15918  ['ABS', 'Blind spot monitor', 'Daytime running...  ['\n4 (Green)\n']
#
#            Gears  Country version
# 0            NaN              NaN
# 1      ['\n7\n']              NaN
# 2            NaN              NaN
# 3      ['\n6\n']              NaN
# 4            NaN  ['\nGermany\n']
# ...          ...              ...
# 15913        NaN              NaN
# 15914  ['\n6\n']              NaN
# 15915  ['\n7\n']  ['\nGermany\n']
# 15916  ['\n6\n']  ['\nAustria\n']
# 15918        NaN  ['\nGermany\n']
#
# [14433 rows x 34 columns]
